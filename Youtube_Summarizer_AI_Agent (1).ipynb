# %% [markdown]
# Youtube Summarizer Agent can quickly extract key insights and main points from any YouTube video. It saves time by providing concise summaries without needing to watch the entire content

# %%
pip uninstall youtube-transcript-api -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping youtube-transcript-api as it is not installed.

# %%
pip install youtube-transcript-api
# Out:
# Collecting youtube-transcript-api
#   Using cached youtube_transcript_api-1.2.4-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\ketki\anaconda3\lib\site-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in c:\users\ketki\anaconda3\lib\site-packages (from youtube-transcript-api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ketki\anaconda3\lib\site-packages (from requests->youtube-transcript-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ketki\anaconda3\lib\site-packages (from requests->youtube-transcript-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ketki\anaconda3\lib\site-packages (from requests->youtube-transcript-api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ketki\anaconda3\lib\site-packages (from requests->youtube-transcript-api) (2025.11.12)
# Using cached youtube_transcript_api-1.2.4-py3-none-any.whl (485 kB)
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-1.2.4
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## **0. Install Dependencies**

# %%
# !pip install Phidata Groq youtube_transcript_api dotenv jira pycountry
# !pip install Phidata Groq dotenv jira pycountry

# firecrawl langchain openai langchain_openai langchain_community pyngrok
# Out:
# Requirement already satisfied: Phidata in c:\users\ketki\anaconda3\lib\site-packages (2.7.10)
# Requirement already satisfied: Groq in c:\users\ketki\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: dotenv in c:\users\ketki\anaconda3\lib\site-packages (0.9.9)
# Requirement already satisfied: jira in c:\users\ketki\anaconda3\lib\site-packages (3.10.5)
# Requirement already satisfied: pycountry in c:\users\ketki\anaconda3\lib\site-packages (26.2.16)
# Requirement already satisfied: docstring-parser in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (0.17.0)
# Requirement already satisfied: gitpython in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (3.1.45)
# Requirement already satisfied: httpx in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (0.28.1)
# Requirement already satisfied: pydantic in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (2.12.4)
# Requirement already satisfied: pydantic-settings in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (2.12.0)
# Requirement already satisfied: python-dotenv in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (1.1.0)
# Requirement already satisfied: pyyaml in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (6.0.3)
# Requirement already satisfied: rich in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (14.2.0)
# Requirement already satisfied: tomli in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (2.2.1)
# Requirement already satisfied: typer in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (0.17.4)
# Requirement already satisfied: typing-extensions in c:\users\ketki\anaconda3\lib\site-packages (from Phidata) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ketki\anaconda3\lib\site-packages (from Groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ketki\anaconda3\lib\site-packages (from Groq) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\ketki\anaconda3\lib\site-packages (from Groq) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\ketki\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->Groq) (3.11)
# Requirement already satisfied: certifi in c:\users\ketki\anaconda3\lib\site-packages (from httpx->Phidata) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\ketki\anaconda3\lib\site-packages (from httpx->Phidata) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ketki\anaconda3\lib\site-packages (from httpcore==1.*->httpx->Phidata) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ketki\anaconda3\lib\site-packages (from pydantic->Phidata) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ketki\anaconda3\lib\site-packages (from pydantic->Phidata) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ketki\anaconda3\lib\site-packages (from pydantic->Phidata) (0.4.2)
# Requirement already satisfied: defusedxml in c:\users\ketki\anaconda3\lib\site-packages (from jira) (0.7.1)
# Requirement already satisfied: packaging in c:\users\ketki\anaconda3\lib\site-packages (from jira) (25.0)
# Requirement already satisfied: requests-oauthlib>=1.1.0 in c:\users\ketki\anaconda3\lib\site-packages (from jira) (2.0.0)
# Requirement already satisfied: requests>=2.10.0 in c:\users\ketki\anaconda3\lib\site-packages (from jira) (2.32.5)
# Requirement already satisfied: requests_toolbelt in c:\users\ketki\anaconda3\lib\site-packages (from jira) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ketki\anaconda3\lib\site-packages (from requests>=2.10.0->jira) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ketki\anaconda3\lib\site-packages (from requests>=2.10.0->jira) (2.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ketki\anaconda3\lib\site-packages (from requests-oauthlib>=1.1.0->jira) (3.3.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ketki\anaconda3\lib\site-packages (from gitpython->Phidata) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ketki\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->Phidata) (4.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ketki\anaconda3\lib\site-packages (from rich->Phidata) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ketki\anaconda3\lib\site-packages (from rich->Phidata) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ketki\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->Phidata) (0.1.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\ketki\anaconda3\lib\site-packages (from typer->Phidata) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ketki\anaconda3\lib\site-packages (from typer->Phidata) (1.5.4)
# Requirement already satisfied: colorama in c:\users\ketki\anaconda3\lib\site-packages (from click>=8.0.0->typer->Phidata) (0.4.6)

# %%
import os
# from google.colab import userdata

# os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
# os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

os.environ["GROQ_API_KEY"] = "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"

# %%
from phi.agent import Agent
from phi.model.groq import Groq
# from phi.model.openai import OpenAIChat
from phi.tools.youtube_tools import YouTubeTools
from dotenv import load_dotenv

agent = Agent(
    # model=Groq(id="llama-3.1-8b-instant"),
    model=Groq(id="llama-3.3-70b-versatile"),  ## Toggle with different LLM model
    # model=OpenAIChat(id="gpt-4o"),
    tools=[YouTubeTools()],
    show_tool_calls=True,
    # debug_mode=True,
    description="""
                  You are a YouTube summarization agent.

                  Steps:
                  1. First try to get captions using get_youtube_video_captions.
                  2. If captions are available → summarize using them.
                  3. If captions are NOT available:
                    - Use get_youtube_video_data
                    - Use title, description, and metadata
                    - Generate a meaningful summary (do NOT say captions unavailable)
                  4. Always provide a useful summary to the user.
"""
)

agent.print_response("Summarize this video https://www.youtube.com/watch?v=tPYj3fFJGjk", markdown=True, stream=True)
# agent.print_response("Use the tool to get captions and summarize this video. URL: https://www.youtube.com/watch?v=tPYj3fFJGjk", markdown=True, stream=True)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### Different models in Groq (optional)**
# Few models in Groq.  More on - https://console.groq.com/docs/models
# 1. gemma2-9b-it
# 2. llama-3.3-70b-versatile
# 3. llama-3.1-8b-instant
# 4. llama3-70b-8192
